# %%
import cv2
import os

# %%
path = "dataset\\train"
image_list = os.listdir(path)
print(image_list)
# Out:
# ['re_composited_gauge_with_shadow_175.jpg', 're_composited_gauge_with_shadow_180.jpg', 're_composited_gauge_with_shadow_185.jpg', 're_composited_gauge_with_shadow_190.jpg', 're_composited_gauge_with_shadow_195.jpg', 're_composited_gauge_with_shadow_200.jpg', 're_composited_gauge_with_shadow_205.jpg', 're_composited_gauge_with_shadow_210.jpg', 're_composited_gauge_with_shadow_215.jpg', 're_composited_gauge_with_shadow_220.jpg', 're_composited_gauge_with_shadow_225.jpg', 're_composited_gauge_with_shadow_230.jpg', 're_composited_gauge_with_shadow_235.jpg', 're_composited_gauge_with_shadow_240.jpg', 're_composited_gauge_with_shadow_245.jpg', 're_composited_gauge_with_shadow_250.jpg', 're_composited_gauge_with_shadow_255.jpg', 're_composited_gauge_with_shadow_260.jpg', 're_composited_gauge_with_shadow_265.jpg', 're_frame0.jpg', 're_frame128.jpg', 're_frame21.jpg', 're_frame22.jpg', 're_frame23.jpg', 're_frame24.jpg', 're_frame25.jpg', 're_frame26.jpg', 're_frame27.jpg', 're_frame30.jpg', 're_frame33.jpg', 're_frame37.jpg', 're_frame39.jpg', 're_frame40.jpg', 're_frame41.jpg', 're_frame43.jpg', 're_frame45.jpg', 're_frame46.jpg', 're_frame48.jpg', 're_frame50.jpg', 're_frame51.jpg', 're_frame52.jpg', 're_frame55.jpg', 're_frame58.jpg', 're_frame59.jpg', 're_frame60.jpg', 're_frame61.jpg', 're_frame65.jpg', 're_frame67.jpg', 're_frame68.jpg', 're_frame70.jpg', 're_frame72.jpg', 're_frame73.jpg', 're_frame76.jpg']

# %%
image_path = []
for file in image_list[:19]:
    file_path = os.path.join(path, file)
    image_path.append(file_path)
print(image_path)
# Out:
# ['dataset\\train\\re_composited_gauge_with_shadow_175.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_180.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_185.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_190.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_195.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_200.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_205.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_210.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_215.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_220.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_225.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_230.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_235.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_240.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_245.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_250.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_255.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_260.jpg', 'dataset\\train\\re_composited_gauge_with_shadow_265.jpg']

# %% [raw]
# for path in image_path:
#     file = os.path.split(path)[-1]
#     file = f"{file[:-3]}jpg"
#     image = cv2.imread(path)
#     cv2.imwrite(f"composite_jpg\\re_{file}", image)
#     # break

# %%
cnt = 129
for path in image_path:
    file = os.path.split(path)[-1]
    image = cv2.imread(path)
    print(image)
    cv2.imwrite(f"test\\re_frame{str(cnt)}.jpg", image)
    cnt += 1
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 254 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [185 190 191]
#   [184 189 190]
#   [184 189 190]]
#
#  [[253 255 255]
#   [253 255 255]
#   [146 150 151]
#   ...
#   [184 189 190]
#   [182 187 188]
#   [180 185 186]]
#
#  [[253 255 255]
#   [253 255 255]
#   [145 149 150]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]]
